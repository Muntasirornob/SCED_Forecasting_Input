# %% [markdown]
# import all libraries here

# %%
import numpy as np
import pandas as pd
from google.colab import drive

# %% [markdown]
# importing data from drive

# %%
drive.mount('/content/gdrive',force_remount=True)
csd_data_frame = pd.read_csv("/content/gdrive/MyDrive/sced_dataset/CSD_Generation.csv")  # CSD data
weather_data_frame =pd.read_csv("/content/gdrive/MyDrive/sced_dataset/en_climate_hourly_AB.csv")  # Historical weather data
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Load the head of the dataset

# %%
csd_data_frame.head()
# Out:
#             Date (MST)           Date (MPT) Asset Short Name  \
# 0  2024-12-01 00:00:00  2024-12-01 00:00:00             ACD1
# 1  2024-12-01 00:00:00  2024-12-01 00:00:00             AFG1
# 2  2024-12-01 00:00:00  2024-12-01 00:00:00             AKE1
# 3  2024-12-01 00:00:00  2024-12-01 00:00:00             ALP1
# 4  2024-12-01 00:00:00  2024-12-01 00:00:00             ALP2
#
#                    Asset Name Asset Grouping     Volume  Maximum Capability  \
# 0          ACD1 Big Sky Solar           ACD1   0.000000               140.0
# 1          AFG1 APF Athabasca           AFG1  65.830041               131.0
# 2  AKE1 McBride Lake Windfarm           AKE1   9.470899                73.0
# 3                 ALP1 Bantry           ALP1   0.000000                 7.0
# 4               ALP2 Parkland           ALP2   0.000000                10.0
#
#    System Capability Fuel Type Sub Fuel Type  Planning Area     Region
# ...

# %%
weather_data_frame.head()
# Out:
#    Longitude (x)  Latitude (y)   Station Name  Climate ID   Date/Time (LST)  \
# 0        -110.32         51.07  ACADIA VALLEY     3020035  2024-12-01 00:00
# 1        -110.32         51.07  ACADIA VALLEY     3020035  2024-12-01 01:00
# 2        -110.32         51.07  ACADIA VALLEY     3020035  2024-12-01 02:00
# 3        -110.32         51.07  ACADIA VALLEY     3020035  2024-12-01 03:00
# 4        -110.32         51.07  ACADIA VALLEY     3020035  2024-12-01 04:00
#
#    Year  Month  Day Time (LST)  Temp (°C)  ...  Wind Spd Flag  \
# 0  2024     12    1      00:00      -15.6  ...            NaN
# 1  2024     12    1      01:00      -15.8  ...            NaN
# 2  2024     12    1      02:00      -16.8  ...            NaN
# 3  2024     12    1      03:00      -17.2  ...            NaN
# 4  2024     12    1      04:00      -17.9  ...            NaN
#
#    Visibility (km)  Visibility Flag  Stn Press (kPa)  Stn Press Flag  Hmdx  \
# ...

# %%
csd_data_frame["timestamp"] = pd.to_datetime(csd_data_frame["Date (MST)"]).dt.date
weather_data_frame["timestamp"] = pd.to_datetime(weather_data_frame["Date/Time (LST)"]).dt.date
weather_data_frame.tail()
# Out:
#      Longitude (x)  Latitude (y)   Station Name  Climate ID   Date/Time (LST)  \
# 739        -110.32         51.07  ACADIA VALLEY     3020035  2024-12-31 19:00
# 740        -110.32         51.07  ACADIA VALLEY     3020035  2024-12-31 20:00
# 741        -110.32         51.07  ACADIA VALLEY     3020035  2024-12-31 21:00
# 742        -110.32         51.07  ACADIA VALLEY     3020035  2024-12-31 22:00
# 743        -110.32         51.07  ACADIA VALLEY     3020035  2024-12-31 23:00
#
#      Year  Month  Day Time (LST)  Temp (°C)  ...  Visibility (km)  \
# 739  2024     12   31      19:00        NaN  ...              NaN
# 740  2024     12   31      20:00        NaN  ...              NaN
# 741  2024     12   31      21:00        NaN  ...              NaN
# 742  2024     12   31      22:00        NaN  ...              NaN
# 743  2024     12   31      23:00        NaN  ...              NaN
#
#      Visibility Flag  Stn Press (kPa)  Stn Press Flag  Hmdx  Hmdx Flag  \
# ...

# %%
csd_data_frame.tail()
# Out:
#                  Date (MST)           Date (MPT) Asset Short Name  \
# 164467  2024-12-31 19:00:00  2024-12-31 19:00:00             YNG1
# 164468  2024-12-31 20:00:00  2024-12-31 20:00:00             YNG1
# 164469  2024-12-31 21:00:00  2024-12-31 21:00:00             YNG1
# 164470  2024-12-31 22:00:00  2024-12-31 22:00:00             YNG1
# 164471  2024-12-31 23:00:00  2024-12-31 23:00:00             YNG1
#
#                    Asset Name Asset Grouping  Volume  Maximum Capability  \
# 164467  YNG1 Youngstown Solar           YNG1     0.0                 6.0
# 164468  YNG1 Youngstown Solar           YNG1     0.0                 6.0
# 164469  YNG1 Youngstown Solar           YNG1     0.0                 6.0
# 164470  YNG1 Youngstown Solar           YNG1     0.0                 6.0
# 164471  YNG1 Youngstown Solar           YNG1     0.0                 6.0
#
#         System Capability Fuel Type Sub Fuel Type  Planning Area   Region  \
# ...

# %%
print("CSD timestamps sample:", csd_data_frame["timestamp"].unique()[:5])
print("Weather timestamps sample:", weather_data_frame["timestamp"].unique()[:5])
# Out:
# CSD timestamps sample: [datetime.date(2024, 12, 1) datetime.date(2024, 12, 2)
#  datetime.date(2024, 12, 3) datetime.date(2024, 12, 4)
#  datetime.date(2024, 12, 5)]
# Weather timestamps sample: [datetime.date(2024, 12, 1) datetime.date(2024, 12, 2)
#  datetime.date(2024, 12, 3) datetime.date(2024, 12, 4)
#  datetime.date(2024, 12, 5)]

# %%
merged_df = pd.merge(csd_data_frame, weather_data_frame, on="timestamp", how="inner")

# %%
merged_df.tail()
# Out:
#                   Date (MST)           Date (MPT) Asset Short Name  \
# 3947323  2024-12-31 23:00:00  2024-12-31 23:00:00             YNG1
# 3947324  2024-12-31 23:00:00  2024-12-31 23:00:00             YNG1
# 3947325  2024-12-31 23:00:00  2024-12-31 23:00:00             YNG1
# 3947326  2024-12-31 23:00:00  2024-12-31 23:00:00             YNG1
# 3947327  2024-12-31 23:00:00  2024-12-31 23:00:00             YNG1
#
#                     Asset Name Asset Grouping  Volume  Maximum Capability  \
# 3947323  YNG1 Youngstown Solar           YNG1     0.0                 6.0
# 3947324  YNG1 Youngstown Solar           YNG1     0.0                 6.0
# 3947325  YNG1 Youngstown Solar           YNG1     0.0                 6.0
# 3947326  YNG1 Youngstown Solar           YNG1     0.0                 6.0
# 3947327  YNG1 Youngstown Solar           YNG1     0.0                 6.0
#
#          System Capability Fuel Type Sub Fuel Type  ...  Wind Spd Flag  \
# ...
